# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("glass.csv")

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.172500    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit(df.drop("Type", axis = 1))
# Out:
# StandardScaler()

# %%
scaled_values = sc.transform(df.drop("Type", axis=1))

# %%
scaled_values
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df['RI']
# Out:
# 0      1.52101
# 1      1.51761
# 2      1.51618
# 3      1.51766
# 4      1.51742
#         ...
# 209    1.51623
# 210    1.51685
# 211    1.52065
# 212    1.51651
# 213    1.51711
# Name: RI, Length: 214, dtype: float64

# %%
df.columns[:-1]
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe'], dtype='object')

# %%
df_values = pd.DataFrame(scaled_values,columns = df.columns[:-1])

# %%
df_values
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# 2   -0.352877 -0.586451
# 3   -0.352877 -0.586451
# 4   -0.352877 -0.586451
# ..        ...       ...
# 209  1.783978 -0.586451
# 210  2.852405 -0.586451
# 211  2.953200 -0.586451
# 212  2.812087 -0.586451
# 213  3.013677 -0.586451
#
# [214 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_values

# %%
y = df['Type']

# %%
X
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# 2   -0.352877 -0.586451
# 3   -0.352877 -0.586451
# 4   -0.352877 -0.586451
# ..        ...       ...
# 209  1.783978 -0.586451
# 210  2.852405 -0.586451
# 211  2.953200 -0.586451
# 212  2.812087 -0.586451
# 213  3.013677 -0.586451
#
# [214 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 133 -0.120610  0.370875  0.865489  0.190912 -1.088259  0.066000 -0.526095
# 169  0.519704 -0.169205 -1.865511  0.632589  0.490551 -0.041582  1.664317
# 5   -0.793931 -0.758384  0.643117  0.351521  0.412905  0.219689 -0.624699
# 158 -0.199825  0.149933  0.504135  0.150759 -0.790614  0.127475 -0.117594
# ..        ...       ...       ...       ...       ...       ...       ...
# 71   0.037818  0.284953  0.823794 -0.351146 -0.894143  0.066000 -0.448621
# 157  0.938879  0.763661  0.747354 -1.736405 -1.114141 -0.594861  0.488115
# 55  -0.222929 -1.175719  0.017697 -0.310994  1.357602  0.096738  0.072571
# 70  -0.866544  1.782449  0.684812  0.592436 -1.010612 -0.518017 -1.124761
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
#
#            Ba        Fe
# 2   -0.352877 -0.586451
# 133 -0.352877  0.956588
# 169 -0.352877 -0.586451
# 5   -0.352877  2.088150
# 158 -0.352877 -0.586451
# ..        ...       ...
# 71  -0.352877  2.705365
# 157 -0.352877 -0.586451
# 55  -0.352877  1.882411
# 70  -0.352877  0.647980
# 1   -0.352877 -0.586451
#
# [171 rows x 9 columns]

# %%
X_test.describe()
# Out:
#               RI         Na         Mg         Al         Si          K  \
# count  43.000000  43.000000  43.000000  43.000000  43.000000  43.000000
# mean   -0.081080  -0.022767   0.091714  -0.020589  -0.002112   0.078509
# std     0.652313   0.804996   0.969192   0.895389   0.731356   1.413905
# min    -1.701594  -2.268155  -1.865511  -1.957244  -2.524717  -0.763919
# 25%    -0.485326  -0.531305  -0.041370  -0.431451  -0.408853  -0.587177
# 50%    -0.226229  -0.095558   0.566677  -0.130308   0.154083   0.081369
# 75%     0.224301   0.389287   0.650066   0.301331   0.535845   0.173582
# max     1.757426   1.966568   1.254639   3.162192   1.072899   8.780145
#
#               Ca         Ba         Fe
# count  43.000000  43.000000  43.000000
# mean   -0.025542  -0.210826  -0.301766
# std     0.826646   0.569503   0.663956
# min    -1.427615  -0.352877  -0.586451
# 25%    -0.571875  -0.352877  -0.586451
# 50%    -0.237327  -0.352877  -0.586451
# 75%     0.100743  -0.352877  -0.586451
# max     2.495405   3.013677   1.882411

# %%
y_train
# Out:
# 2      1
# 133    2
# 169    5
# 5      1
# 158    3
#       ..
# 71     2
# 157    3
# 55     1
# 70     2
# 1      1
# Name: Type, Length: 171, dtype: int64

# %%
y_test
# Out:
# 170    5
# 154    3
# 6      1
# 43     1
# 137    2
# 183    6
# 172    5
# 119    2
# 81     2
# 12     1
# 33     1
# 96     2
# 134    2
# 173    5
# 155    3
# 140    2
# 177    6
# 115    2
# 165    5
# 18     1
# 13     1
# 139    2
# 30     1
# 0      1
# 98     2
# 38     1
# 53     1
# 182    6
# 3      1
# 117    2
# 61     1
# 49     1
# 99     2
# 213    7
# 89     2
# 73     2
# 199    7
# 144    2
# 146    3
# 181    6
# 179    6
# 24     1
# 116    2
# Name: Type, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %%
pred
# Out:
# array([2, 2, 1, 3, 2, 2, 5, 2, 2, 1, 1, 1, 1, 2, 1, 2, 6, 2, 5, 1, 1, 2,
#        1, 1, 2, 1, 1, 5, 1, 2, 1, 1, 1, 7, 2, 2, 7, 1, 1, 6, 6, 1, 2])

# %%
y_test
# Out:
# 170    5
# 154    3
# 6      1
# 43     1
# 137    2
# 183    6
# 172    5
# 119    2
# 81     2
# 12     1
# 33     1
# 96     2
# 134    2
# 173    5
# 155    3
# 140    2
# 177    6
# 115    2
# 165    5
# 18     1
# 13     1
# 139    2
# 30     1
# 0      1
# 98     2
# 38     1
# 53     1
# 182    6
# 3      1
# 117    2
# 61     1
# 49     1
# 99     2
# 213    7
# 89     2
# 73     2
# 199    7
# 144    2
# 146    3
# 181    6
# 179    6
# 24     1
# 116    2
# Name: Type, dtype: int64

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.93      0.79        14
#            2       0.73      0.73      0.73        15
#            3       0.00      0.00      0.00         3
#            5       0.67      0.50      0.57         4
#            6       1.00      0.60      0.75         5
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.72        43
#    macro avg       0.68      0.63      0.64        43
# weighted avg       0.70      0.72      0.70        43

# %%
error_rate = []

# %%
for i in range(1, 50):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
error_rate
# Out:
# [0.27906976744186046,
#  0.3023255813953488,
#  0.2558139534883721,
#  0.3023255813953488,
#  0.27906976744186046,
#  0.32558139534883723,
#  0.3488372093023256,
#  0.37209302325581395,
#  0.4186046511627907,
#  0.37209302325581395,
#  0.4418604651162791,
#  0.4186046511627907,
#  0.4186046511627907,
#  0.4186046511627907,
#  0.3488372093023256,
#  0.4418604651162791,
#  0.3953488372093023,
#  0.4418604651162791,
#  0.4186046511627907,
#  0.46511627906976744,
#  0.4418604651162791,
#  0.3953488372093023,
#  0.4186046511627907,
#  0.4186046511627907,
#  0.4418604651162791,
#  0.4186046511627907,
#  0.4186046511627907,
#  0.46511627906976744,
#  0.4883720930232558,
#  0.46511627906976744,
#  0.5116279069767442,
#  0.5116279069767442,
#  0.5116279069767442,
#  0.46511627906976744,
#  0.46511627906976744,
#  0.46511627906976744,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.4883720930232558,
#  0.5116279069767442,
#  0.5116279069767442]

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,50),error_rate)

# %%
knn = KNeighborsClassifier(n_neighbors=8)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
pred = knn.predict(X_test)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.59      0.93      0.72        14
#            2       0.65      0.73      0.69        15
#            3       0.00      0.00      0.00         3
#            5       1.00      0.25      0.40         4
#            6       0.00      0.00      0.00         5
#            7       0.67      1.00      0.80         2
#
#     accuracy                           0.63        43
#    macro avg       0.48      0.49      0.43        43
# weighted avg       0.54      0.63      0.55        43
# /Users/smanoj008/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/smanoj008/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/smanoj008/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
pred = knn.predict(X_test)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.55      0.79      0.65        14
#            2       0.58      0.73      0.65        15
#            3       0.00      0.00      0.00         3
#            5       0.50      0.25      0.33         4
#            6       0.00      0.00      0.00         5
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.58        43
#    macro avg       0.44      0.46      0.44        43
# weighted avg       0.47      0.58      0.51        43
# /Users/smanoj008/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/smanoj008/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/smanoj008/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
